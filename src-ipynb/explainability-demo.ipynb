# %%
# %load_ext autoreload

# %%
import sys
sys.path.insert(0, '../../style_generation_pipeline')

# %autoreload
# %matplotlib ipympl
from data import *
from cluster_representation import *
from visualize_clusters import *
from IPython.display import display, Javascript, HTML
import IPython.display as display

# %%
import ipywidgets as widgets

output = widgets.Output()
display.display(output)
# Out:
# Output()

# %%
# interp_space_path    = '../datasets/hiatus_data/system2_interp_space_clusters_09/'
# instances_to_explain = '../datasets/hiatus_data/hrs_explanations.json'
interp_space_path    = '../datasets/hiatus_data/luar_clusters_07/'
instances_to_explain = '../datasets/hiatus_data/hrs_explanations.json'

style_feat_clm = 'llm_tfidf_weights'
top_k=10
only_llm_feats=False
only_gram2vec_feats=False

# %%
instance_explanations = json.load(open(instances_to_explain))
interp_space = load_interp_space(interp_space_path, style_feat_clm, top_k, only_llm_feats, only_gram2vec_feats)

# %%
instance_id = 0

# %%
print('Model Prediction:',  instance_explanations[instance_id]['latent_rank'], 
      'Interp Prediction:', instance_explanations[instance_id]['interp_rank'],
      'Selected Clusters:', instance_explanations[instance_id]['rep_clusters'],
)
# Out:
# Model Prediction: [2, 1, 0] Interp Prediction: [1, 0, 2] Selected Clusters: [21, 34, 47]

# %%
visualize_clusters(interp_space, instance_explanations[instance_id], output)
display.display(HTML(instance_explanations[instance_id]['authors_texts_as_html']))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Label Studio HTML</title>
#     <style>
#         .container {
#             overflow: auto;
#             border: solid 1px black;
#             padding: 10px;
#             margin: 0px 20px 5px 0px;
#         }
#         .flex-container {
#             display: flex;
#         }
#         .flex-item {
#             flex: 33%;
#             padding: 10px;
#             margin: 0px 20px 5px 0px;
#             border: solid 1px black;
#         }
#         h3 {
#             text-decoration: underline;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h3>Mystery Author</h3>
#         <p id="query-text">Document 1:
# Growth on My Dog's Eye
#
# ...
